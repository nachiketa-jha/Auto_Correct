# %%
import pandas as pd

# %%
df = pd.read_csv('cricket_data_2025.csv')

# %%
df.head(10)
# Out:
#      Year       Player_Name Matches_Batted  Not_Outs Runs_Scored  \
# 0     NaN      Aaron Hardie       No stats  No stats    No stats
# 1  2024.0       Abdul Samad             16         2         182
# 2  2023.0       Abdul Samad              9         4         169
# 3  2022.0       Abdul Samad              2         0           4
# 4  2021.0       Abdul Samad             11         1         111
# 5  2020.0       Abdul Samad             12         3         111
# 6     NaN  Abhinandan Singh       No stats  No stats    No stats
# 7  2024.0   Abhinav Manohar              2         0           9
# 8  2023.0   Abhinav Manohar              9         0         114
# 9  2022.0   Abhinav Manohar              8         1         108
#
#   Highest_Score Batting_Average Balls_Faced Batting_Strike_Rate Centuries  \
# 0      No stats        No stats    No stats            No stats  No stats
# 1           37*            18.2         108              168.52         0
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df_cleaned = df.dropna(subset=['Year'])

# %%
df_cleaned['Runs_Scored'].value_counts()
# Out:
# Runs_Scored
# 0       136
# 1        33
# 2        22
# 7        17
# 0.0      16
# 9        13
# 6        11
# 3        11
# 12       10
# 5        10
# 13       10
# 4        10
# 42        9
# 21        9
# 8         9
# 20        7
# 14        7
# 10        6
# 37        6
# 19        6
# 11        6
# 16        6
# 18        5
# 17        5
# 59        5
# 111       5
# 40        5
# 146       4
# 143       4
# 15        4
# 357       4
# 83        4
# 52        4
# 227       4
# 183       4
# 43        4
# 101       4
# 50        4
# 22        4
# 33        4
# 182       4
# 404       3
# 191       3
# 145       3
# 362       3
# 161       3
# 206       3
# 230       3
# 62        3
# 186       3
# 77        3
# 34        3
# 188       3
# 117       3
# 488       3
# 30        3
# 333       3
# 168       3
# 332       3
# 358       3
# 301       3
# 303       3
# 396       3
# 86        3
# 418       3
# 160       3
# 250       3
# 36        3
# 31        3
# 397       3
# ...

# %%
df_cleaned['Player_Name'].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_cleaned['Player_Name'].unique().count
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'
